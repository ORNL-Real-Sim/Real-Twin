# %% [raw]
# ##############################################################################
# # Copyright (c) 2024-, Oak Ridge National Laboratory                          #
# # All rights reserved.                                                       #
# #                                                                            #
# # This file is part of RealTwin and is distributed under a GPL               #
# # license. For the licensing terms see the LICENSE file in the top-level     #
# # directory.                                                                 #
# #                                                                            #
# # Contributors: ORNL Real-Twin Team                                          #
# # Contact: realtwin@ornl.gov                                                 #
# ##############################################################################

# %% [markdown]
# ## Please refer to our official documentation for more details on RealTwin preparation before running the simulation

# %%
import realtwin as rt

# %%
# Step 1: Prepare your configuration file (in YAML format)

CONFIG_FILE = "./realtwin_config.yaml"

# %%
# In case you don't know where to get the template configuration file, you can create a template configuration file using code below

# rt.prepare_realtwin_configs()

# %%
# Step 2: initialize the realtwin object
# In this step, realtwin package will load the configuration file and prepare global variables for future use.

twin = rt.RealTwin(input_config_file=CONFIG_FILE, verbose=True)
# Out:
# [16:17:10]   :Coordinate order is ambiguous. Assuming (lon, lat) format.                       ]8;id=426299;file://D:\ORNL\Real-Twin\Real-Twin-Dev\realtwin\func_lib\_b_load_inputs\loader_config.py\loader_config.py]8;;\:]8;id=993524;file://D:\ORNL\Real-Twin\Real-Twin-Dev\realtwin\func_lib\_b_load_inputs\loader_config.py#105\105]8;;\

# %%
# Step 3: check simulator env: if SUMO, VISSIM, Aimsun, etc... are installed

# Check whether selected simulator installed on your operation system.
# If not, install the simulator (for SUMO), print out message to let user know (for Other Simulator)
# Currently accepted simulators are: SUMO, VISSIM, AIMSUN

twin.env_setup(sel_sim=["SUMO", "VISSIM"])
# Out:
# Check / Install the selected simulators:
#   :Checking SUMO installation on Windows.
#   :SUMO version: 1.21.0 found: C:/Program Files (x86)/Eclipse/Sumo/bin/sumo.exe
#   :SUMO is already installed, available versions: ['1.21.0']
#   :Could not install vissim (strict version) on your operation system
# "  :Info: Selected simulators: ['sumo'] are installed successfully."

# %%
# # Step 4: Create Matchup Table from SUMO network

# twin.generate_inputs()

# %%
# Step 4 (Warning!): if you have your updated / personal sumo network file (rather than downloaded from OpenStreetMap)

updated_sumo_net = r"./datasets/MLK/MLK_elevation_no_signals.net.xml"
twin.generate_inputs(incl_sumo_net=updated_sumo_net)
# Out:
# Check / Create input files and folders for user:
#   :Control folder exists: D:/ORNL/Real-Twin/Real-Twin-Dev/datasets/MLK/Control.
#   :NOTICE: Please include Synchro UTDF file (signal) inside Control folder
#   :Traffic folder exists: D:/ORNL/Real-Twin/Real-Twin-Dev/datasets/MLK/Traffic.
#   :NOTICE: Please include turn movement file for each intersection inside Traffic folder and add the file names to the MatchupTable.xlsx (You will notice the generated MatchupTable.xlsx inside your input folder). For how to fill the MatchupTable.xlsx, please refer to official documentation
# D:\ORNL\Real-Twin\Real-Twin-Dev\venv\Lib\site-packages\rich\live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
#   :INFO: SUMO network is copied to D:/ORNL/Real-Twin/Real-Twin-Dev/datasets/MLK/output/OpenDrive/MLK_elevation_no_signals.net.xml.
#   :Using updated SUMO network provide by user: D:/ORNL/Real-Twin/Real-Twin-Dev/datasets/MLK/MLK_elevation_no_signals.net.xml to generate OpenDrive network.
# D:\ORNL\Real-Twin\Real-Twin-Dev\venv\Lib\site-packages\rich\live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# D:\ORNL\Real-Twin\Real-Twin-Dev\venv\Lib\site-packages\rich\live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
#   :NOTE: Matchup table is generated and saved to D:/ORNL/Real-Twin/Real-Twin-Dev/datasets/MLK/MatchupTable.xlsx.
#   :NOTICE: Please update the Matchup table from input folder and then run generate_abstract_scenario(). For details please refer to official documentation:
# ─ Program stopped. Please prepare the Control and Traffic data and fill in the Matchup Table before proceeding. … ─
# ⚠ Please update the generated Matchup table from input folder before pressing Enter or type 'y' / 'yes' to continue
#   :INFO: User confirmed to continue (Matchup Table Updated).
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# '  :Info: Please prepare the Control and Traffic data and save them to the input directory. Please also fill in the Matchup Table at D:/ORNL/Real-Twin/Real-Twin-Dev/datasets/MLK/MatchupTable.xlsx.\n'

# %% [markdown]
# ### Before step 5, there are three steps to be performed:
# ### 1. Prepare Traffic Demand and save it to Traffic Folder in input directory
# ### 2. Prepare Control Data (Signal) and save it to Control Folder in input directory
# ### 3. Manually fill in the Matchup Table in the input directory

# %%
# Step 5: generate abstract scenario

# 1. Automatically fill in the Matchup Table from traffic and control
# 2. Save the filled Matchup Table to the input directory
# 3. Manually edit / fixed the Matchup Table if needed

twin.generate_abstract_scenario()
# Out:
#   :INFO: Using Matchup Table: D:/ORNL/Real-Twin/Real-Twin-Dev/datasets/MLK/MatchupTable.xlsx
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202587081.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202587081.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202608349.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202608349.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202608349.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202608349.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202633693.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202633693.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202633693.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202633693.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202645406.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202645406.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202645406.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202645406.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202692612.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202692612.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202692612.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202692612.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202695945.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202695945.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202695945.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202695945.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202695945.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202695945.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202695945.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202695945.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202695945.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202695945.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202695971.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202695971.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202695971.
#   :There are more turning movements in Synchro_signal.csv than OpenDrive junction 202695971.
# ⚠ In the Matchup Table, please check if the turn movement in the demand and control data match with bearings in the
# network data. Enter any key to continue...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 7
#       1 # Step 5: generate abstract scenario
#       2
#       3 # 1. Automatically fill in the Matchup Table from traffic and control
#       4 # 2. Save the filled Matchup Table to the input directory
#       5 # 3. Manually edit / fixed the Matchup Table if needed
# ----> 7 twin.generate_abstract_scenario()
#
# File D:\ORNL\Real-Twin\Real-Twin-Dev\realtwin\_realtwin.py:348, in RealTwin.generate_abstract_scenario(self)
#     343 if self._input_confirm:
#     344     # Tell user to manually check correctness of the Matchup Table
#     345     console.input(":warning: [bold magenta]In the Matchup Table, please check if the turn movement in the "
#     346                   "demand and control data match with bearings in the network data. Enter any key to continue...")
# --> 348 df_volume, df_vol_lookup = generate_turn_demand(path_matchup_table=path_matchup,
#     349                                                 control_dir=control_dir,
#     350                                                 traffic_dir=traffic_dir,)
#     352 self.abstract_scenario.Traffic.VolumeLookupTable = df_vol_lookup
#     354 self.abstract_scenario.update_AbstractScenario_from_input(df_volume=df_volume)
#
# File D:\ORNL\Real-Twin\Real-Twin-Dev\realtwin\func_lib\_c_abstract_scenario\rt_demand_generation.py:519, in generate_turn_demand(path_matchup_table, control_dir, traffic_dir, output_dir)
#     516 TurnDf = pd.concat(TurnDf_list, ignore_index=True) if TurnDf_list else pd.DataFrame()
#     518 IDRef = pd.concat(IDRef_list, ignore_index=True) if IDRef_list else pd.DataFrame()
# --> 519 IDRef = IDRef[["IntersectionName", "Turn", "OpenDriveFromID", "OpenDriveToID"]]
#     521 if output_dir:
#     522     # Ensure the output directory exists
#     523     os.makedirs(output_dir, exist_ok=True)
#
# File D:\ORNL\Real-Twin\Real-Twin-Dev\venv\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File D:\ORNL\Real-Twin\Real-Twin-Dev\venv\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File D:\ORNL\Real-Twin\Real-Twin-Dev\venv\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['IntersectionName', 'Turn', 'OpenDriveFromID', 'OpenDriveToID'], dtype='object')] are in the [columns]"

# %%
# Step 6: generate scenarios

twin.generate_concrete_scenario()
# Out:
# Concrete Scenario successfully generated.

# %%
# Step 7: simulate the scenario

twin.prepare_simulation()
# Out:
#   :Route file generated successfully: D:/ORNL/Real-Twin/Real-Twin-Dev/datasets/Roosevelt/output/SUMO/roosevelt.rou.xml
#   :Synchro intersection (id = 3) has more movements than SUMO junction (id = cluster_1923791237_2203813886_2231137214_5913291209_#3more). Please check.
#   :All red time ('AllRed') is missing for phase 1 at intersection 4, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 2 at intersection 4, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 2 at intersection 4, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 3 at intersection 4, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 4 at intersection 4, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 4 at intersection 4, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 5 at intersection 4, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 6 at intersection 4, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 6 at intersection 4, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 7 at intersection 4, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 8 at intersection 4, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 8 at intersection 4, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 1 at intersection 2, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 2 at intersection 2, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 2 at intersection 2, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 3 at intersection 2, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 4 at intersection 2, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 4 at intersection 2, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 5 at intersection 2, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 6 at intersection 2, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 6 at intersection 2, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 7 at intersection 2, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 8 at intersection 2, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 8 at intersection 2, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 1 at intersection 1, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 2 at intersection 1, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 2 at intersection 1, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 3 at intersection 1, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 4 at intersection 1, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 4 at intersection 1, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 5 at intersection 1, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 6 at intersection 1, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 6 at intersection 1, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 7 at intersection 1, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 8 at intersection 1, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 8 at intersection 1, 2 sec is used.
#   :Minimum green('MinGreen') is missing for phase 4 at intersection 3, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 4 at intersection 3, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 7 at intersection 3, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 8 at intersection 3, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 8 at intersection 3, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 1 at intersection 5, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 2 at intersection 5, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 2 at intersection 5, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 3 at intersection 5, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 4 at intersection 5, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 4 at intersection 5, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 5 at intersection 5, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 6 at intersection 5, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 6 at intersection 5, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 7 at intersection 5, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 8 at intersection 5, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 8 at intersection 5, 2 sec is used.
#   :Minimum green('MinGreen') is missing for phase 2 at intersection 7, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 2 at intersection 7, 2 sec is used.
#   :Minimum green('MinGreen') is missing for phase 4 at intersection 7, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 4 at intersection 7, 2 sec is used.
#   :Minimum green('MinGreen') is missing for phase 6 at intersection 7, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 6 at intersection 7, 2 sec is used.
#   :Minimum green('MinGreen') is missing for phase 8 at intersection 7, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 8 at intersection 7, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 1 at intersection 6, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 2 at intersection 6, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 2 at intersection 6, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 3 at intersection 6, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 4 at intersection 6, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 4 at intersection 6, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 5 at intersection 6, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 6 at intersection 6, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 6 at intersection 6, 2 sec is used.
#   :All red time ('AllRed') is missing for phase 7 at intersection 6, 0 sec is used.
#   :Minimum green('MinGreen') is missing for phase 8 at intersection 6, 6 sec is used
#   :Added green per actuation ('vehext') is missing for phase 8 at intersection 6, 2 sec is used.
#   :SUMO signal updated at: D:/ORNL/Real-Twin/Real-Twin-Dev/datasets/Roosevelt/output/SUMO/roosevelt.net.xml
# SUMO simulation successfully Prepared.
# True

# %%
# Step 8: perform calibration, Available algorithms: GA: Genetic Algorithm, SA: Simulated Annealing, TS: Tabu Search
twin.calibrate(sel_algo={"turn_inflow": "GA", "behavior": "GA"})

# %%
 # Step 9 (ongoing): post-process the simulation results
twin.post_process()  # keyword arguments can be passed to specify the post-processing options

# Step 10 (ongoing): visualize the simulation results
twin.visualize()  # keyword arguments can be passed to specify the visualization options
